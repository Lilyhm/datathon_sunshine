# %%
import pandas as pd

internal = pd.read_csv('Datathon_CHA_activities_2016-2020.csv')
internal.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  HubRandomID  Hub_ActivityID ActivityDate  ProgrammeID  \
# 0           0        15994             259       4/3/19           50
# 1           1        15994             260      25/2/19           50
# 2           2        15994             261      11/3/19           50
# 3           3        15994             262      18/3/19           50
# 4           4        15994             263       4/2/19           50
#
#    ChildParticipants  AdultParticipants DSS_ClientParticipants  \
# 0                 11                  7                     18
# 1                 12                  8                     20
# 2                  0                  0                      0
# 3                 12                  8                     20
# 4                 10                  6                     16
#
#    ReferralParticipants  EngagedCount     ...     ProgrammeID.1  \
# 0                     0             0     ...                50
# 1                     0             0     ...                50
# 2                     0             0     ...                50
# 3                     0             0     ...                50
# 4                     0             0     ...                50
#
#                 ProgrammeName ProgrammeCategoryID   ShortName  ServiceTypeID  \
# 0  Playgroups and Early Years                   1  Playgroups              4
# 1  Playgroups and Early Years                   1  Playgroups              4
# 2  Playgroups and Early Years                   1  Playgroups              4
# 3  Playgroups and Early Years                   1  Playgroups              4
# 4  Playgroups and Early Years                   1  Playgroups              4
#
#    ProgrammeCategoryID.1           CategoryName Status.1 StartDate ShortName.1
# 0                      1  Programmed Activities        C    1/1/10        PROG
# 1                      1  Programmed Activities        C    1/1/10        PROG
# 2                      1  Programmed Activities        C    1/1/10        PROG
# 3                      1  Programmed Activities        C    1/1/10        PROG
# 4                      1  Programmed Activities        C    1/1/10        PROG
#
# [5 rows x 31 columns]

# %%
pd.set_option('max_columns', 180)

# %%
internal.columns
# Out:
# Index(['Unnamed: 0', 'HubRandomID', 'Hub_ActivityID', 'ActivityDate',
#        'ProgrammeID', 'ChildParticipants', 'AdultParticipants',
#        'DSS_ClientParticipants', 'ReferralParticipants', 'EngagedCount',
#        'LastModifiedBy', 'LastModifiedDateTime', 'StartTime', 'EndTime',
#        'ExternalVolunteers', 'HubVolunteers', 'SchoolVolunteers', 'Status',
#        'LastModifiedBy.1', 'LastModifiedDateTime.1', 'IsActive',
#        'ProgrammeID.1', 'ProgrammeName', 'ProgrammeCategoryID', 'ShortName',
#        'ServiceTypeID', 'ProgrammeCategoryID.1', 'CategoryName', 'Status.1',
#        'StartDate', 'ShortName.1'],
#       dtype='object')

# %%
internal['EngagedCount'].value_counts()
# Out:
# 0    163150
# Name: EngagedCount, dtype: int64

# %%
internal.columns
# Out:
# Index(['Unnamed: 0', 'HubRandomID', 'Hub_ActivityID', 'ActivityDate',
#        'ProgrammeID', 'ChildParticipants', 'AdultParticipants',
#        'DSS_ClientParticipants', 'ReferralParticipants', 'EngagedCount',
#        'LastModifiedBy', 'LastModifiedDateTime', 'StartTime', 'EndTime',
#        'ExternalVolunteers', 'HubVolunteers', 'SchoolVolunteers', 'Status',
#        'LastModifiedBy.1', 'LastModifiedDateTime.1', 'IsActive',
#        'ProgrammeID.1', 'ProgrammeName', 'ProgrammeCategoryID', 'ShortName',
#        'ServiceTypeID', 'ProgrammeCategoryID.1', 'CategoryName', 'Status.1',
#        'StartDate', 'ShortName.1'],
#       dtype='object')

# %%
internal = internal[['HubRandomID', 'Hub_ActivityID', 'ActivityDate',
       'ProgrammeID', 'ChildParticipants', 'AdultParticipants', 'ProgrammeName', 'CategoryName']]

internal.describe(include='all')
# Out:
#           HubRandomID  Hub_ActivityID ActivityDate    ProgrammeID  \
# count   163150.000000   163150.000000       163150  163150.000000
# unique            NaN             NaN          430            NaN
# top               NaN             NaN     18/12/17            NaN
# freq              NaN             NaN         1079            NaN
# mean     15189.556200   520290.987882          NaN      53.758388
# std       2971.128235   179883.068454          NaN       7.080064
# min      10011.000000      259.000000          NaN      45.000000
# 25%      12394.000000   534350.250000          NaN      48.000000
# 50%      14935.000000   575137.500000          NaN      50.000000
# 75%      18154.000000   616184.750000          NaN      59.000000
# max      19871.000000   670065.000000          NaN      73.000000
#
#         ChildParticipants  AdultParticipants      ProgrammeName  \
# count       163150.000000      163150.000000             163150
# unique                NaN                NaN                 29
# top                   NaN                NaN  Parent engagement
# freq                  NaN                NaN              27936
# mean             5.988685           3.782654                NaN
# std             29.027974          15.705990                NaN
# min              0.000000           0.000000                NaN
# 25%              0.000000           0.000000                NaN
# 50%              0.000000           0.000000                NaN
# 75%              2.000000           4.000000                NaN
# max           2000.000000        1500.000000                NaN
#
#                  CategoryName
# count                  163150
# unique                      4
# top     Programmed Activities
# freq                    88458
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
len(internal['HubRandomID'].unique())
# Out:
# 80

# %% [markdown]
# What does the 'typical hub' look like in terms of
# - engagement
# - diversity of programs
# - activities for children and adults
#
# Normalise this between hubs. Is number of participants a good enough metric? Get distibution of engagement
#
# How have the above trended over time?
#
# Manual clustering - and seeing how hubs are indexed compared to the population.
#
# Categorise into high/low

# %%
pd.set_option('max_columns', 180)
# pd.set_option('max_rows', 200000)
# pd.set_option('max_colwidth', 5000)

# %%
internal.describe(include = 'all')
# Out:
#            Unnamed: 0    HubRandomID  Hub_ActivityID ActivityDate  \
# count   163150.000000  163150.000000   163150.000000       163150
# unique            NaN            NaN             NaN          430
# top               NaN            NaN             NaN     13/11/17
# freq              NaN            NaN             NaN         1079
# mean     81574.500000   15189.556200   520290.987882          NaN
# std      47097.492546    2971.128235   179883.068454          NaN
# min          0.000000   10011.000000      259.000000          NaN
# 25%      40787.250000   12394.000000   534350.250000          NaN
# 50%      81574.500000   14935.000000   575137.500000          NaN
# 75%     122361.750000   18154.000000   616184.750000          NaN
# max     163149.000000   19871.000000   670065.000000          NaN
#
#           ProgrammeID  ChildParticipants  AdultParticipants  \
# count   163150.000000      163150.000000      163150.000000
# unique            NaN                NaN                NaN
# top               NaN                NaN                NaN
# freq              NaN                NaN                NaN
# mean        53.758388           5.988685           3.782654
# std          7.080064          29.027974          15.705990
# min         45.000000           0.000000           0.000000
# 25%         48.000000           0.000000           0.000000
# 50%         50.000000           0.000000           0.000000
# 75%         59.000000           2.000000           4.000000
# max         73.000000        2000.000000        1500.000000
#
#         DSS_ClientParticipants  ReferralParticipants  EngagedCount  \
# count                 163150.0         163150.000000      163150.0
# unique                   508.0                   NaN           NaN
# top                        0.0                   NaN           NaN
# freq                   84598.0                   NaN           NaN
# mean                       NaN              1.006184           0.0
# std                        NaN             11.856494           0.0
# min                        NaN              0.000000           0.0
# 25%                        NaN              0.000000           0.0
# 50%                        NaN              0.000000           0.0
# 75%                        NaN              0.000000           0.0
# max                        NaN           1188.000000           0.0
#
#        LastModifiedBy LastModifiedDateTime StartTime   EndTime  \
# count          163150               163150     27134     27134
# unique              3                10562        78        98
# top               dbo              41:12.8   9:00:00  11:00:00
# freq           147448               119337      7274      2926
# mean              NaN                  NaN       NaN       NaN
# std               NaN                  NaN       NaN       NaN
# min               NaN                  NaN       NaN       NaN
# 25%               NaN                  NaN       NaN       NaN
# 50%               NaN                  NaN       NaN       NaN
# 75%               NaN                  NaN       NaN       NaN
# max               NaN                  NaN       NaN       NaN
#
#         ExternalVolunteers  HubVolunteers  SchoolVolunteers  Status  \
# count        163150.000000  163150.000000     163150.000000  163150
# unique                 NaN            NaN               NaN       6
# top                    NaN            NaN               NaN  Closed
# freq                   NaN            NaN               NaN  120045
# mean              0.062679       0.053472          0.043898     NaN
# std               1.829064       0.497211          2.901615     NaN
# min               0.000000       0.000000          0.000000     NaN
# 25%               0.000000       0.000000          0.000000     NaN
# 50%               0.000000       0.000000          0.000000     NaN
# 75%               0.000000       0.000000          0.000000     NaN
# max             500.000000      28.000000        580.000000     NaN
#
#         LastModifiedBy.1 LastModifiedDateTime.1       IsActive  ProgrammeID.1  \
# count             163150                 163150  163150.000000  163150.000000
# unique                 3                     10            NaN            NaN
# top     unisuper\SheelaN                23:39.9            NaN            NaN
# freq              151819                  80335            NaN            NaN
# mean                 NaN                    NaN       0.952718      53.758388
# std                  NaN                    NaN       0.212241       7.080064
# min                  NaN                    NaN       0.000000      45.000000
# 25%                  NaN                    NaN       1.000000      48.000000
# 50%                  NaN                    NaN       1.000000      50.000000
# 75%                  NaN                    NaN       1.000000      59.000000
# max                  NaN                    NaN       1.000000      73.000000
#
#             ProgrammeName  ProgrammeCategoryID ShortName  ServiceTypeID  \
# count              163150        163150.000000    163150  163150.000000
# unique                 29                  NaN        29            NaN
# top     Parent engagement                  NaN   Parents            NaN
# freq                27936                  NaN     27936            NaN
# mean                  NaN             1.793325       NaN      14.966601
# std                   NaN             0.919536       NaN      36.204133
# min                   NaN             1.000000       NaN       2.000000
# 25%                   NaN             1.000000       NaN       2.000000
# 50%                   NaN             1.000000       NaN       4.000000
# 75%                   NaN             3.000000       NaN      10.000000
# max                   NaN             5.000000       NaN     145.000000
#
#         ProgrammeCategoryID.1           CategoryName Status.1 StartDate  \
# count           163150.000000                 163150   163150    163150
# unique                    NaN                      4        1         1
# top                       NaN  Programmed Activities        C    1/1/10
# freq                      NaN                  88458   163150    163150
# mean                 1.793325                    NaN      NaN       NaN
# std                  0.919536                    NaN      NaN       NaN
# min                  1.000000                    NaN      NaN       NaN
# 25%                  1.000000                    NaN      NaN       NaN
# 50%                  1.000000                    NaN      NaN       NaN
# 75%                  3.000000                    NaN      NaN       NaN
# max                  5.000000                    NaN      NaN       NaN
#
#        ShortName.1
# count       163150
# unique           4
# top           PROG
# freq         88458
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# correlations between
# - number of activities overall and number of participants - ratio?
# - number of different kinds of activities and participants
#
# indexing - compare to population
#
# indexing over time - do any behave differently?
#
#
# attributes - who are they
# behaviours - what have they done, what will they do?
# recommendations - what should they do, what should we do?
#
# developers.google.com/machine-learning/guides/good-data-analysis
# validation
# evaluation
# description
